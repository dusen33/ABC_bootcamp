# %% [markdown]
# # 나와 가장 가까운 무료 WIFI 찾기
#
# *   2020년 지역별 WIFI 설치현황.csv

# %% [markdown]
# ## 패키지 설치 및 라이브러리 임포트

# %%
pip install koreanize-matplotlib

# %%
import pandas as pd

import plotly.express as px
import koreanize_matplotlib

import folium

# %% [markdown]
# ## 데이터 준비하기

# %%
df = pd.read_csv('/content/2020년 지역별 WIFI 설치현황.csv', encoding='EUC-KR')
df
# Out:
#          설치시도명 설치시군구명 설치시설구분 서비스제공사명 설치년월  관리기관명         위도          경도  \
# 0      제주특별자치도   서귀포시   편의시설      KT  NaN  정보정책과  33.251523  126.559351
# 1      제주특별자치도   서귀포시   편의시설      KT  NaN  정보정책과  33.251523  126.559351
# 2      제주특별자치도   서귀포시   교통시설      KT  NaN  정보정책과  33.251395  126.559516
# 3      제주특별자치도   서귀포시   교통시설      KT  NaN  정보정책과  33.251395  126.559516
# 4      제주특별자치도   서귀포시     관광      KT  NaN  정보정책과  33.249872  126.559884
# ...        ...    ...    ...     ...  ...    ...        ...         ...
# 25664  제주특별자치도   서귀포시     관광      KT  NaN  정보정책과  33.246478  126.556058
# 25665  제주특별자치도   서귀포시     관광      KT  NaN  정보정책과  33.246478  126.556058
# 25666  제주특별자치도   서귀포시     관광      KT  NaN  정보정책과  33.246822  126.556491
# 25667  제주특별자치도   서귀포시     관광      KT  NaN  정보정책과  33.246822  126.556491
# 25668  제주특별자치도   서귀포시     관광      KT  NaN  정보정책과  33.246822  126.556491
#
#           데이터기준일자
# 0      2020-10-28
# 1      2020-10-28
# 2      2020-10-28
# 3      2020-10-28
# 4      2020-10-28
# ...           ...
# 25664  2020-10-28
# 25665  2020-10-28
# 25666  2020-10-28
# 25667  2020-10-28
# 25668  2020-10-28
#
# [25669 rows x 9 columns]

# %% [markdown]
# ## 데이터 확인하기

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25669 entries, 0 to 25668
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   설치시도명    25669 non-null  object
#  1   설치시군구명   25669 non-null  object
#  2   설치시설구분   25669 non-null  object
#  3   서비스제공사명  25669 non-null  object
#  4   설치년월     20252 non-null  object
#  5   관리기관명    25669 non-null  object
#  6   위도       25669 non-null  float64
#  7   경도       25669 non-null  float64
#  8   데이터기준일자  25669 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 1.8+ MB

# %%
# 전체 데이터 결측치 확인하기
df.isna().sum()
# Out:
# 설치시도명         0
# 설치시군구명        0
# 설치시설구분        0
# 서비스제공사명       0
# 설치년월       5417
# 관리기관명         0
# 위도            0
# 경도            0
# 데이터기준일자       0
# dtype: int64

# %%
# 설치시설구분의 중복을 제외한 값 확인하기
df['설치시설구분'].unique()
# Out:
# array(['편의시설', '교통시설', '관광', '주요거리', '공원', '공공기관', '복지센터등', '관공서',
#        '서민·복지시설', '기타', '문화관광', '전통시장', '버스승차대', '지역문화시설', '서민/복지시설',
#        '교육시설', '공공도서관', '공원내', '민원실', '쉼터', '휴게실', '박물관', '시장', '도서관',
#        '노인복지회관', '행정복지센터', '다중이용시설', '버스정류장', '관광지역', '관광지', '복지시설',
#        '보건지소', '정류장', '버스', '관광시설', '보건진료소', '서민복지시설', '터미널', '종합복지시설',
#        '읍/면/동 주민센터', ' 서민·복지시설', '보건소', '공공(일반)', '주민자치센터', '노인정',
#        '문화체육시설', '버스터미널'], dtype=object)

# %%
len(df['설치시설구분'].unique())
# Out:
# 47

# %%
len(df['설치시도명'].unique())
# Out:
# 17

# %%
# 서비스제공사명을 제외한 값 확인하기
df['서비스제공사명'].unique()
# Out:
# array(['KT', '서울시(SAW)', '서대문구', 'SKT', '서울시(LGU )', 'LGU+',
#        '서울특별시 영등포구청', 'LGU', '성남시청', '광주도시관리공사', 'SKT,LGU+,경기도 광주시청',
#        'SKT,경기도 광주시청', '경기도 광주시청', '서울특별시 양천구청', 'SKB', '경상북도 경주시청', 'SK',
#        'LG U+', '강원도 고성군청, LGU+', '강원도 고성군청, KT', 'LG헬로', '부산광역시', '화성시',
#        '강남구', '서울특별시 강서구', '구로구(자체구축)', '용인시', '광명시', '헬로 TV', '미래부(SKT)',
#        '서울시(삼성)', '미래부(LGU+)', 'LG', '서울시(SKT)', '서울특별시', '강북구청', '서울시',
#        '성동구', '미래부(KT)', 'SK,KT,LG', 'SKT, LGU+', '울주군', 'LG U +',
#        'SKT, LG', '서울특별시 은평구청', '미래부', 'KT/LG U+', '서울특별시시(SKT)', '동두천시',
#        '북구', '안산시', '대구시자가통신망', 'KT,LGU+', '광양시청', 'SKT&KT',
#        'SKT Giga WiFi', '㈜KT', 'LGU+,KT', 'SKT,LGU+', '양주시', '서울특별시시(KT)',
#        '서울시(KT)', '도봉구청', '울산광역시 중구', 'SKT,KT', 'JCN', 'CJ헬로비전', '서울특별시청',
#        '서울특별시 동대문구청', '과기부', 'SK브로드밴드', '시장상인회', '자체설치', 'KT(구청 자체 설치)',
#        '서경방송', '서울특별시 송파구', '기존', '구내회선', '하남시', '과천시', 'Public WiFi',
#        '서울특별시 종로구', 'KT+SKB', '하동군', 'SKT,KT,LGU+', '의령군', '경상북도 안동시',
#        '통영시', '경상남도 합천군청', 'KT, SKT', 'KT, SKT, LGU+', 'KT, LGU+',
#        '경기도 파주시', '충주시', '서초구', '시흥시', '부천시', '나주공공도서관', '목포공공도서관',
#        '서울특별시 관악구청', '(주)엘지유플러스', '㈜케이티', '금천구청', 'SK-B', '현대HCN 새로넷방송',
#        'KT/LGU+', '과학기술정보통신부', '강원랜드', 'LG U+,KT', 'SKB+LGU+', 'Lgu+',
#        'LGT', 'KT올레', '서울특별시 강북구청', '강원도 고성군청, KT (통신사개방)',
#        '국회의정연수원, KT (통신사 개방)', '시청', '무선인터넷', 'SK텔레콤', 'SKT, KT',
#        'SKT, KT, LGU+', 'SKT/LGU+', '김대중컨벤션센터', '김해시', '자가망', '무선와이파이',
#        '용산구', '경기도 광주시청 청소년수련관', '보은군청', '경기도광명시', '마포구청', '경기도 안양시',
#        '청도공영사업공사', '안양방송', 'public WiFi free', '기장군청', '충청북도 영동군',
#        '서울 중구청', '포항시', '광주광역시', '서울특별시시(LGU+)', 'LGU+, SKT(신관)',
#        '광주광역시 남구청', '오산시', '성북구', '경상북도 청도군', '㈜딜라이브경동케이블', 'LG유플러스',
#        '경상북도 영주시', '시', '안산도시공사', '달성군', '동구청', 'KISTI', '중랑구청', '㈜나인콤',
#        '(주)KT', '㈜도원', '㈜SK', '안성시청', 'kT', '광진구청', 'KT,SKT',
#        'KT,SKT,LGU+', '경기도 구리시', '밀양시청', '보령시'], dtype=object)

# %%
len(df['서비스제공사명'].unique())
# Out:
# 167

# %% [markdown]
# ## 데이터 전처리

# %% [markdown]
# ### 설치시설구분 컬럼 데이터 전처리

# %%
# '서민·복지시설','서민/복지시설','서민복지시설',' 서민·복지시설' ->'서민·복지시설' 전처리
# loc 서민이라는 단어 contains 되있는 것을 찾고 원하는 단어로 치환
df.loc[df['설치시설구분'].str.contains('서민'),'설치시설구분'] = '서민·복지시설'
df['설치시설구분'].unique()
# Out:
# array(['편의시설', '교통시설', '관광', '주요거리', '공원', '공공기관', '복지센터등', '관공서',
#        '서민·복지시설', '기타', '문화관광', '전통시장', '버스승차대', '지역문화시설', '교육시설',
#        '공공도서관', '공원내', '민원실', '쉼터', '휴게실', '박물관', '시장', '도서관', '노인복지회관',
#        '행정복지센터', '다중이용시설', '버스정류장', '관광지역', '관광지', '복지시설', '보건지소', '정류장',
#        '버스', '관광시설', '보건진료소', '터미널', '종합복지시설', '읍/면/동 주민센터', '보건소',
#        '공공(일반)', '주민자치센터', '노인정', '문화체육시설', '버스터미널'], dtype=object)

# %%
df['설치시설구분'].value_counts()
# Out:
# 관공서           8782
# 서민·복지시설       3727
# 기타            3063
# 교통시설          2787
# 관광            2300
# 편의시설          2143
# 지역문화시설        1817
# 교육시설           321
# 공원             123
# 버스정류장          112
# 주요거리           101
# 관광지             62
# 복지센터등           41
# 다중이용시설          41
# 버스              37
# 공공기관            33
# 문화관광            32
# 전통시장            27
# 정류장             16
# 보건지소            14
# 행정복지센터          13
# 보건소             10
# 민원실              9
# 시장               7
# 보건진료소            6
# 복지시설             5
# 관광시설             5
# 노인정              4
# 공원내              4
# 공공도서관            4
# 버스승차대            4
# 주민자치센터           3
# 문화체육시설           3
# 휴게실              2
# 공공(일반)           2
# 읍/면/동 주민센터       1
# 도서관              1
# 종합복지시설           1
# 터미널              1
# 관광지역             1
# 노인복지회관           1
# 박물관              1
# 쉼터               1
# 버스터미널            1
# Name: 설치시설구분, dtype: int64

# %% [markdown]
# ## 지역별 WIFI 설치 현황 분석

# %% [markdown]
# ### 설치시도별 설치시설구분과 서비스제공사 설치현황 집계표 만들기

# %%
group_df =df.groupby(by=['설치시도명','설치시설구분','서비스제공사명']).size().reset_index(name='설치수')
group_df # type: 시리즈
# Out:
#     설치시도명 설치시설구분    서비스제공사명  설치수
# 0     강원도    관공서  (주)엘지유플러스    7
# 1     강원도    관공서         KT  134
# 2     강원도    관공서      LG U+   40
# 3     강원도    관공서       LGU+   82
# 4     강원도    관공서        SKT  107
# ..    ...    ...        ...  ...
# 956  충청북도   편의시설         KT   22
# 957  충청북도   편의시설        SKT   15
# 958  충청북도   편의시설       보은군청    3
# 959  충청북도   편의시설        충주시    1
# 960  충청북도   편의시설   충청북도 영동군    3
#
# [961 rows x 4 columns]

# %% [markdown]
# ### 서비스제공사별 설치현황 시각화

# %%
group_df['서비스제공사명'].value_counts()
# Out:
# KT            145
# LGU+          114
# SKT           113
# LG U+          42
# SK             33
#              ...
# 안양방송            1
# ㈜딜라이브경동케이블      1
# 밀양시청            1
# 도봉구청            1
# 보은군청            1
# Name: 서비스제공사명, Length: 167, dtype: int64

# %%
px.histogram(group_df, x = '서비스제공사명', y = '설치수')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="242125f2-31fc-4668-a690-4b4807590742" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("242125f2-31fc-4668-a690-4b4807590742")) {                    Plotly.newPlot(                        "242125f2-31fc-4668-a690-4b4807590742",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"\uc11c\ube44\uc2a4\uc81c\uacf5\uc0ac\uba85=%{x}<br>sum of \uc124\uce58\uc218=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["(\uc8fc)\uc5d8\uc9c0\uc720\ud50c\ub7ec\uc2a4","KT","LG U+","LGU+","SKT","\u321c\ucf00\uc774\ud2f0","\uac15\uc6d0\ub3c4 \uace0\uc131\uad70\uccad, KT","\uac15\uc6d0\ub3c4 \uace0\uc131\uad70\uccad, KT (\ud1b5\uc2e0\uc0ac\uac1c\ubc29)","\uac15\uc6d0\ub3c4 \uace0\uc131\uad70\uccad, LGU+","\uad6d\ud68c\uc758\uc815\uc5f0\uc218\uc6d0, KT (\ud1b5\uc2e0\uc0ac \uac1c\ubc29)","(\uc8fc)\uc5d8\uc9c0\uc720\ud50c\ub7ec\uc2a4","KT","LG U+","LGU+","SKT","\u321c\ucf00\uc774\ud2f0","\uac15\uc6d0\ub3c4 \uace0\uc131\uad70\uccad, KT","\uac15\uc6d0\ub79c\ub4dc","(\uc8fc)\uc5d8\uc9c0\uc720\ud50c\ub7ec\uc2a4","KT","LG U+","SKT","(\uc8fc)\uc5d8\uc9c0\uc720\ud50c\ub7ec\uc2a4","KT","LG U+","LGU+","SKT","KT","LG U+","LGU+","SKT","\u321c\ucf00\uc774\ud2f0","\uac15\uc6d0\ub3c4 \uace0\uc131\uad70\uccad, KT","\uac15\uc6d0\ub3c4 \uace0\uc131\uad70\uccad, LGU+","(\uc8fc)\uc5d8\uc9c0\uc720\ud50c\ub7ec\uc2a4","(\uc8fc)\uc5d8\uc9c0\uc720\ud50c\ub7ec\uc2a4","KT","LG U+","LGU+","LGU+, SKT(\uc2e0\uad00)","SKB","SKT","(\uc8fc)\uc5d8\uc9c0\uc720\ud50c\ub7ec\uc2a4","KT","LG U+","LGU+","SKT","\uac15\uc6d0\ub3c4 \uace0\uc131\uad70\uccad, KT","\uac15\uc6d0\ub3c4 \uace0\uc131\uad70\uccad, LGU+","KT","LG U+","LGU+","SKT","\uac15\uc6d0\ub3c4 \uace0\uc131\uad70\uccad, LGU+","KT","SKT","\ud558\ub0a8\uc2dc","\uacbd\uae30\ub3c4 \uc548\uc591\uc2dc","KT","SKT","KT","KT, SKT","LG U+","LGU+","SKB","
uc11c","\uad00\uacf5\uc11c","\uad00\uacf5\uc11c","\uad00\uacf5\uc11c","\uad00\uacf5\uc11c","\uad00\uacf5\uc11c","\uad00\uacf5\uc11c","\uad00\uacf5\uc11c","\uad00\uad11","\uad00\uad11","\uad00\uad11","\uad00\uad11","\uad00\uad11","\uad50\uc721\uc2dc\uc124","\uad50\uc721\uc2dc\uc124","\uad50\uc721\uc2dc\uc124","\uad50\uc721\uc2dc\uc124","\uad50\uc721\uc2dc\uc124","\uad50\uc721\uc2dc\uc124","\uad50\uc721\uc2dc\uc124","\uad50\uc721\uc2dc\uc124","\uad50\ud1b5\uc2dc\uc124","\uad50\ud1b5\uc2dc\uc124","\uad50\ud1b5\uc2dc\uc124","\uad50\ud1b5\uc2dc\uc124","\uad50\ud1b5\uc2dc\uc124","\uad50\ud1b5\uc2dc\uc124","\uad50\ud1b5\uc2dc\uc124","\uad50\ud1b5\uc2dc\uc124","\uad50\ud1b5\uc2dc\uc124","\uad50\ud1b5\uc2dc\uc124","\uae30\ud0c0","\uae30\ud0c0","\uae30\ud0c0","\uae30\ud0c0","\uae30\ud0c0","\uae30\ud0c0","\uae30\ud0c0","\uae30\ud0c0","\uae30\ud0c0","\uae30\ud0c0","\uae30\ud0c0","\uae30\ud0c0","\uae30\ud0c0","\uae30\ud0c0","\uae30\ud0c0","\uae30\ud0c0","\uae30\ud0c0","\ub178\uc778\ubcf5\uc9c0\ud68c\uad00","\ub3c4\uc11c\uad00","\ubbfc\uc6d0\uc2e4","\ubbfc\uc6d0\uc2e4","\ubbfc\uc6d0\uc2e4","\ubc15\ubb3c\uad00","\ubc84\uc2a4\uc815\ub958\uc7a5","\uc11c\ubbfc\u00b7\ubcf5\uc9c0\uc2dc\uc124","\uc11c\ubbfc\u00b7\ubcf5\uc9c0\uc2dc\uc124","\uc11c\ubbfc\u00b7\ubcf5\uc9c0\uc2dc\uc124 ...

# %% [markdown]
# ## 서울특별시 무료 WIFI 현황 데이터 분석 및 시각화

# %% [markdown]
# ### 서울특별시 데이터 준비하기

# %%
#sl_df = df[df['설치시도명']=='서울특별시']
sl_df = df.loc[df['설치시도명']=='서울특별시'] # FM
sl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5185 entries, 27 to 25360
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   설치시도명    5185 non-null   object
#  1   설치시군구명   5185 non-null   object
#  2   설치시설구분   5185 non-null   object
#  3   서비스제공사명  5185 non-null   object
#  4   설치년월     3979 non-null   object
#  5   관리기관명    5185 non-null   object
#  6   위도       5185 non-null   float64
#  7   경도       5185 non-null   float64
#  8   데이터기준일자  5185 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 405.1+ KB

# %% [markdown]
# ### 서울특별시(구별)는 어떤 목적으로 무료 WIFI를 설치했나

# %%
# 구로구 -> 왜 기타만 많은지 확인
# 성동구 -> 왜 지역문화시설 많은지 확인
# 광진구 -> 관광  -> 지도 시각화 확인 필요
# 서대문구 -> 주요거리 뭔지 확인 필요
# 강남구 -> 편의시설
# 지도 시각화 할 때 설치시설구분으로 마커 다르게 표출
fig = px.histogram(sl_df, x = '설치시군구명', color='설치시설구분')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id
11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc740\ud3c9\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"\uc124\uce58\uc2dc\uc124\uad6c\ubd84=\uacf5\uc6d0<br>\uc124\uce58\uc2dc\uad70\uad6c\uba85=%{x}<br>count=%{y}<extra></extra>","legendgroup":"\uacf5\uc6d0","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"\uacf5\uc6d0","offsetgroup":"\uacf5\uc6d0","orientation":"v","show ...

# %% [markdown]
# ### 가장 많은 WIFI 설치가 되어 있는 구는 어디?

# %%
sl_group_df = sl_df.groupby(by = ['설치시군구명', '설치시설구분', '서비스제공사명']).size().reset_index(name='설치수')
sl_group_df
# Out:
#     설치시군구명  설치시설구분        서비스제공사명  설치수
# 0      강남구     관공서  SKT Giga WiFi   18
# 1      강남구     관공서            강남구  134
# 2      강남구     관공서        미래부(KT)   10
# 3      강남구     관공서     서울특별시시(KT)    2
# 4      강남구    교통시설     서울특별시시(KT)    2
# ..     ...     ...            ...  ...
# 204    종로구  지역문화시설      서울특별시 종로구    6
# 205     중구     관공서         서울 중구청  114
# 206     중구      기타         서울 중구청   13
# 207     중구  지역문화시설         서울 중구청   10
# 208    중랑구     관공서           중랑구청   86
#
# [209 rows x 4 columns]

# %%
fig = px.pie(sl_group_df, names = '설치시군구명',  values = '설치수')
fig.update_traces(textposition='inside', textinfo = 'percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="17829512-ee1b-441a-9269-d98919766191" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17829512-ee1b-441a-9269-d98919766191")) {                    Plotly.newPlot(                        "17829512-ee1b-441a-9269-d98919766191",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":
uc791\uad6c","\ub3d9\uc791\uad6c","\ub3d9\uc791\uad6c","\ub3d9\uc791\uad6c","\ub3d9\uc791\uad6c","\ub3d9\uc791\uad6c","\ub3d9\uc791\uad6c","\ub3d9\uc791\uad6c","\ub3d9\uc791\uad6c","\ub3d9\uc791\uad6c","\ub3d9\uc791\uad6c","\ub3d9\uc791\uad6c","\ub9c8\ud3ec\uad6c","\ub9c8\ud3ec\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\ub300\ubb38\uad6c","\uc11c\uc6b8\ud2b9\ubcc4\uc2dc \ub3c4\ubd09\uad6c","\uc11c\uc6b8\ud2b9\ubcc4\uc2dc \ub3c4\ubd09\uad6c","\uc11c\uc6b8\ud2b9\ubcc4\uc2dc \ub3c4\ubd09\uad6c","\uc11c\ucd08\uad6c","\uc11c\ucd08\uad6c","\uc11c\ucd08\uad6c","\uc11c\ucd08\uad6c","\uc131\ub3d9\uad6c","\uc131\ub3d9\uad6c","\uc131\ub3d9\uad6c","\uc131\ub3d9\uad6c","\uc131\ub3d9\uad6c","\uc131\ub3d9\uad6c","\uc131\ub3d9\uad6c","\uc131\ub3d9 ...

# %% [markdown]
# ## 내 위치와 가장 가까운 무료 WIFI 찾아서 지도 시각화하기

# %% [markdown]
# ### 사용자의 위도 경도 추출하기

# %%
# 도로명 주소를 입력하면 -> 좌표값으로 변환 -> 지도에 표출
from geopy.geocoders import Nominatim

# 도로명 주소를 입력하면 좌표값을 반환하는 함수 선언
def geocoding(address):
  geocoder = Nominatim(user_agent='South Korea', timeout = None)
  geo = geocoder.geocode(address)
  crd = {"lat":float(geo.latitude), "lng":float(geo.longitude)}

  return crd

address = input("도로명 주소를 입력하세요")
crd = geocoding(address)
print(crd)
print('위도', crd['lat'])
print('경도', crd['lng'])

# 지도에 시각화
my_map = folium.Map(location=[crd['lat'], crd['lng']], zoom_start=13)
folium.Marker([crd['lat'], crd['lng']], icon = folium.Icon(color='red', icon='fa-home', prefix='fa')).add_to(my_map)
my_map
# Out:
# 도로명 주소를 입력하세요대전광역시 유성구 궁동
# {'lat': 36.3665161, 'lng': 127.3462828}
# 위도 36.3665161
# 경도 127.3462828
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de02aed6afa40171f6c3204bee4f3a4e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de02aed6afa40171f6c3204bee4f3a4e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de02aed6afa40171f6c3204bee4f3a4e = L.map(
#                 &quot;map_de02aed6afa40171f6c3204bee4f3a4e&quot;,
#                 {
#                     center: [36.3665161, 127.3462828],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1121e2c4354a663d32f2ea33ae62e733 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_de02aed6afa40171f6c3204bee4f3a4e);
#
#
#             var marker_3a0e53be07a3a6d42ad52a6a766dce83 = L.marker(
#                 [36.3665161, 127.3462828],
#                 {}
#             ).addTo(map_de02aed6afa40171f6c3204bee4f3a4e);
#
#
#             var icon_df7c3bae21e46b1a4d0efa019ea55635 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3a0e53be07a3a6d42ad52a6a766dce83.setIcon(icon_df7c3bae21e46b1a4d0efa019ea55635);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 내 위치에서 가장 가까운 WIFI top10 찾기

# %%
# 모든 WIFI 위치 좌표와 내 위치 좌표 거리 계산 -> 가장 가까운 (짧은 거리) TOP10
# 좌표 거리 계산 필요

from geopy.distance import geodesic

# 지도 시각화에 필요한 정보만 담은 df 재정의
my_wifi_df = pd.DataFrame(columns=['설치시군구명', '설치시설구분', '위도', '경도', '거리'])

# 거리 계싼을 하려면 좌표값을 튜플 형태로 제공해야 함
my_home = (crd['lat'], crd['lng'])

for n in df.index:
  wifi_loc = (df.loc[n, '위도'], df.loc[n, '경도']) # 거리 계산을 위해 튜플 형태로 저장
  # my_wifi_df 데이터 담기
  my_wifi_df.loc[n] = [df.loc[n, '설치시군구명'], df.loc[n, '설치시설구분'],
                       df.loc[n, '위도'], df.loc[n, '경도'],
                       geodesic(my_home, wifi_loc).kilometers]

my_wifi_df.head()
# Out:
#   설치시군구명 설치시설구분         위도          경도          거리
# 0   서귀포시   편의시설  33.251523  126.559351  352.985855
# 1   서귀포시   편의시설  33.251523  126.559351  352.985855
# 2   서귀포시   교통시설  33.251395  126.559516  352.996736
# 3   서귀포시   교통시설  33.251395  126.559516  352.996736
# 4   서귀포시     관광  33.249872  126.559884  353.155419

# %% [markdown]
# ### 내 위치와 가장 가까운 무료 WIFI TOP10 찾기

# %%
my_wifi_top10 = my_wifi_df.sort_values(by=["거리"]).head(10)

# %% [markdown]
# ### 내 위치와 가장 가까운 무료 WIFI top10 지도 시각화

# %%
my_map = folium.Map(location=[crd['lat'], crd['lng']], zoom_start=13)

for n in my_wifi_top10.index:
  folium.Marker([my_wifi_top10.loc[n, '위도'], my_wifi_top10.loc[n, '경도']],
                popup = '<pre>' + my_wifi_top10.loc[n, '설치시설구분'] + '</pre>',
                icon = folium.Icon(color='blue', icon='wifi', prefix='fa')).add_to(my_map)

folium.Marker([crd['lat'], crd['lng']],
              icon = folium.Icon(color='red', icon='fa-home', prefix='fa')).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b4961b38dc97418fd78226fdc7c7ba8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b4961b38dc97418fd78226fdc7c7ba8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b4961b38dc97418fd78226fdc7c7ba8 = L.map(
#                 &quot;map_1b4961b38dc97418fd78226fdc7c7ba8&quot;,
#                 {
#                     center: [36.3665161, 127.3462828],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5c1ca456a78edda3dc5f343536accbfc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1b4961b38dc97418fd78226fdc7c7ba8);
#
#
#             var marker_dd962e817b3538f07cc32d7a2acb27be = L.marker(
#                 [36.360683, 127.357671],
#                 {}
#             ).addTo(map_1b4961b38dc97418fd78226fdc7c7ba8);
#
#
#             var icon_9c2cc0ea28f30ab32e57b975dcc9d5f0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;wifi&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_dd962e817b3538f07cc32d7a2acb27be.setIcon(icon_9c2cc0ea28f30ab32e57b975dcc9d5f0);
#
#
#         var popup_ac1de84173f25379aa35ddf201947b1a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4f588a6015bb920f13206141b9a8aa1e = $(`&lt;div id=&quot;html_4f588a6015bb920f13206141b9a8aa1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt;지역문화시설&lt;/pre&gt;&lt;/div&gt;`)[0];
#                 popup_ac1de84173f25379aa35ddf201947b1a.setContent(html_4f588a6015bb920f13206141b9a8aa1e);
#
#
#
#         marker_dd962e817b3538f07cc32d7a2acb27be.bindPopup(popup_ac1de84173f25379aa35ddf201947b1a)
#         ;
#
#
#
#
#             var marker_7f52b985e997a907f8a27ddc2756a0de = L.marker(
#                 [36.35467883, 127.3575866],
#                 {}
#             ).addTo(map_1b4961b38dc97418fd78226fdc7c7ba8);
#
#
#             var icon_820c48b8e86a64586cf9842766800d2d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;wifi&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7f52b985e997a907f8a27ddc2756a0de.setIcon(icon_820c48b8e86a64586cf9842766800d2d);
#
#
#         var popup_e88333a418eb7d3e1c48d1db17d3a8b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_655bc7ef5348e189d7c50a03b05bfbd6 = $(`&lt;div id=&quot;html_655bc7ef5348e189d7c50a03b05bfbd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt;관공서&lt;/pre&gt;&lt;/div&gt;`)[0];
#                 popup_e88333a418eb7d3e1c48d1db17d3a8b5.setContent(html_655bc7ef5348e189d7c50a03b05bfbd6);
#
#
#
#         marker_7f52b985e997a907f8a27ddc2756a0de.bindPopup(popup_e88333a418eb7d3e1c48d1db17d3a8b5)
#         ;
#
#
#
#
#             var marker_77ac58a4997814b4d344bfa96ba4d99a = L.marker(
#                 [36.36201743, 127.3661059],
#                 {}
#             ).addTo(map_1b4961b38dc97418fd78226fdc7c7ba8);
#
#
#             var icon_c0a2d574f3e321c5b7ac441080503d04 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;wifi&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_77ac58a4997814b4d344bfa96ba4d99a.setIcon(icon_c0a2d574f3e321c5b7ac441080503d04);
#
#
#         var popup_fead5afac7969dbea9be93dc7f415b2a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f8f98c7f1ff7f51ea3bd8238efef44c6 = $(`&lt;div id=&quot;html_f8f98c7f1ff7f51ea3bd8238efef44c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt;서민·복지시설&lt;/pre&gt;&lt;/div&gt;`)[0];
#                 popup_fead5afac7969dbea9be93dc7f415b2a.setContent(html_f8f98c7f1ff7f51ea3bd8238efef44c6);
#
#
#
#         marker_77ac58a4997814b4d344bfa96ba4d99a.bindPopup(popup_fead5afac7969dbea9be93dc7f415b2a)
#         ;
#
#
#
#
#             var marker_be342a2f78aa3a41485aa6c8df7e019c = L.marker(
#                 [36.35915939, 127.3647689],
#                 {}
#             ).addTo(map_1b4961b38dc97418fd78226fdc7c7ba8);
#
#
#             var icon_b44949047186299685c3ee4e0b2cbfa6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
